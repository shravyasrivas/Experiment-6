# %% [markdown]
# Experiment 6:
# Aim:Study of conditional Statements in python
# Shravya Srivastava 25070123106

# %%
''' 1a. check whether a number is positive, negative
    1b. check a number is positive,negative or zero.'''
for _ in range(3):
 num =int(input("enter a number:"))
 if num > 0 :
  print("positive number")
 elif num < 0:
  print("negative number")
 else:
  print("zero")
# Out:
# enter a number:5
# positive number
# enter a number:-6
# negative number
# enter a number:0
# zero

# %%
#2. check whether a given number is even or odd
num = int(input("enter a number "))
if num % 2 == 0:
  print("even number"  )
else:
  print("odd number")
# Out:
# enter a number 7
# odd number

# %%
#3. Identify the greater number from a b and c
a = int(input("enter a number "))
b = int(input("enter b number "))
c = int (input("enter c number "))
if a>b and a>c: # usw and operator and not & if we use that it is a bit wise operator if we use this 0 neagtive postive mein diff nhi kar payega
  print("a is greater")

elif b>a and b>c:
  print("b is greater")
else:
  print("c is greater")
# Out:
# enter a number 2
# enter b number -6
# enter c number 0
# a is greater

# %%
#4. get input from user for 1 subject and find the grade using if elif and else statement\ no algorithm
mark= int(input("enter your marks:"))
#metrics: 75>a,60> b, 40>c,<40 f and >90a
if mark>= 90:
  print("A grade")
elif mark>=75:
  print("B grade")
elif mark>= 60:
  print("C grade")
elif mark >=40 :
  print ("D grade")
else:
  print("F grade")
# Out:
# enter your marks58
# D grade

# %%
#5. get input from user for 3 subjects and find average and grade the student:
a= int(input("enter your marks in maths:"))
b= int (input("enter your marks in english:"))
c= int(input("enter your makks in feee:"))
mark=(a+b+c)/3
print("Average garde is :", mark)
if mark>= 90:
  print("A grade")
elif mark>=75:
  print("B grade")
elif mark>= 60:
  print("C grade")
elif mark >=40 :
  print ("D grade")
else:
  print("F grade")
# Out:
# enter your marks in maths:99
# enter your marks in english:29
# enter your makks in feee:70
# Average garde is : 66.0
# C grade

# %%
#6. Check if a year is a leap year
yr= int(input("enter year:"))
if (yr % 4 == 0 and yr % 100 !=0) or (yr % 400==0):# problem comes when yr is 1900
  print("Year is leap")
else:
  print("Year is not leap")
# Out:
# enter year:6487
# Year is not leap

# %%
#7. Write a program to print the next date
date=input("ente date in format {dd/mm/yyyy}:")
dd,mm,yyyy=date.split('/')
dd=int(dd)
mm=int(mm)
yyyy=int(yyyy)
if (mm==1 or mm==3 or mm==5 or mm==7 or mm==8 or mm==10 or mm==12):
  days=31
elif(mm==4 or mm==6 or mm==9 or mm==11):
  days=30
elif(yy%4==0 and yy%100!=0 or yy%400==0):
  days=29
else:
  days=28
if (mm<1 or mm>12):
  print("date is invalid")
elif(dd<1 or dd>days):
  print("date is invalid")
elif(dd==days and mm!=12) :
  dd=1
  mm=mm+1
  print("incremented date is:",dd,"/",mm,"/",yyyy)
elif(dd==31 and mm==12):
  dd=1
  mm=1
  yyyy=yyyy+1
  print("incremented date is:",dd,"/",mm,"/",yyyy)
else:
  dd=dd+1
  print("incremented date is:",dd,"/",mm,"/",yyyy)
# Out:
# ente date in format {dd/mm/yyyy}:30/04/1222
# incremented date is: 1 5 1222

# %%
#8. check if input is a vowel or a consonant
c=input("enter a letter:")
if c in 'aieouAEIOU':
  print("vowel")
else:
  print("consonant")
# Out:
# enter a letteri
# vowel

# %%
''' 9. write a python program to calculate the gross salary of an employee
if basic <= 10000: HRA = 20% , DA=80%
if basic <= 20000: HRA = 25%, DA=90%
otherwise : HRA = 30% , DA=95%'''
basic= int(input("Enter basic salary:"))
if basic <=10000:
 hra= basic * 0.20
 da= basic * 0.80
elif basic <= 20000:
 hra= basic * 0.25
 da= basic * 0.90
else:
 hra= basic * 0.30
 da= basic * 0.95
gross = basic+ hra+ da
print("gross salay is:",gross)
# Out:
# Enter basic salary:120000
# gross salay is: 270000.0

# %%
''' 10. write a python program to calculate income tax based on annual income:
up to ₹2,50,000: no tax
₹2,50,001 - ₹5,00,000 : 5%
₹5,00,001 - ₹10,00,000: 20%
above ₹10,00,000 :30 %'''

i=float(input("enter annual income:"))
if i  <=250000:
  tax=0
  print("tax:", tax)
elif 250001<=i <= 500000:
  taxi= i-250000
  tax= taxi*0.05
  print("tax:", tax)
elif 500001<=i<= 1000000:
  taxi=i-250000
  taxi1= taxi*0.05
  taxii=500000- taxi
  taxi2= taxii*0.20
  taxf= taxi1+taxi2
  print("tax:", taxf)
else :
  taxi=i-250000
  taxi1= taxi*0.05
  taxii=500000- taxi
  taxi2= taxii*0.20
  taxiii= 1000000-taxii
  taxi3= taxiii*0.30
  taxf= taxi1+taxi2+taxi3
  print("tax:", taxf)
# Out:
# enter annual income:560000
# tax: 53500.0
